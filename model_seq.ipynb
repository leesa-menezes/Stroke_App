# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# %%
data = pd.read_csv("stroke.csv", index_col=0)

# %%
data.head()
# Out:
#        gender   age  hypertension  alcohol_intake  heart_disease ever_married  \
# id
# 9046     Male  67.0           147               2              1          Yes
# 51676  Female  61.0           135               4              0          Yes
# 31112    Male  80.0           115               3              1          Yes
# 60182  Female  49.0           125               2              0          Yes
# 1665   Female  79.0           130               3              0          Yes
#
#            work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# id
# 9046         Private          Urban             228.69  36.6  formerly smoked
# 51676  Self-employed          Rural             202.21   NaN     never smoked
# 31112        Private          Rural             105.92  32.5     never smoked
# 60182        Private          Urban             171.23  34.4           smokes
# 1665   Self-employed          Rural             174.12  24.0     never smoked
#
#        stroke
# id
# 9046        1
# 51676       1
# 31112       1
# 60182       1
# 1665        1

# %%
data['hypertension'] = data['hypertension'].astype(float) 
data['alcohol_intake'] = data['alcohol_intake'].astype(float)

# %%
data = data.drop("ever_married" , axis=1)
data = data.drop("work_type" , axis=1)

# %%
for column in data.columns:
    if data[column].dtype == np.number:
        continue
    data[column] = LabelEncoder().fit_transform( data[column] )

# %%
data = data.fillna(data.mean())

# %%
X = data.drop(["stroke"], axis=1)
Y = data["stroke"]

# %%
x_scaler = MinMaxScaler()
x_scaler.fit(X)
column_names = X.columns
X[column_names]=x_scaler.transform(X)

# %%
X.head()
# Out:
#        gender       age  hypertension  alcohol_intake  heart_disease  \
# id
# 9046      1.0  0.816895      0.858974        0.333333            1.0
# 51676     0.0  0.743652      0.782051        0.666667            0.0
# 31112     1.0  0.975586      0.653846        0.500000            1.0
# 60182     0.0  0.597168      0.717949        0.333333            0.0
# 1665      0.0  0.963379      0.750000        0.500000            0.0
#
#        Residence_type  avg_glucose_level       bmi  smoking_status
# id
# 9046              1.0           0.801173  0.301260        0.333333
# 51676             0.0           0.678875  0.215380        0.666667
# 31112             0.0           0.234159  0.254296        0.666667
# 60182             1.0           0.535793  0.276060        1.000000
# 1665              0.0           0.549141  0.156930        0.666667

# %%
X=np.array(X)
Y= np.array(Y)

# %%
from imblearn.over_sampling import SMOTE 
sm = SMOTE(random_state = 2) 
X_res, Y_res = sm.fit_sample(X,Y.ravel())

# %%
print("After OverSampling, counts of label '1': {}".format(sum(Y_res == 1))) 
print("After OverSampling, counts of label '0': {}".format(sum(Y_res == 0)))
# Out:
# After OverSampling, counts of label '1': 2751
# After OverSampling, counts of label '0': 2751

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation,Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.metrics import binary_crossentropy

# %%
model = Sequential([
    Dense(32, input_shape=(X_res.shape[1],), activation='relu'),
    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    Dense(2, activation='softmax'),    
])

# %%
model.compile(optimizer=Adam(learning_rate = 0.0001),
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %%
model.fit(X_res,Y_res,validation_split=0.1,batch_size=10,epochs=145,shuffle=True,verbose=2)
# Out:
# Train on 4951 samples, validate on 551 samples
# Epoch 1/145
# 4951/4951 - 3s - loss: 0.6922 - accuracy: 0.5678 - val_loss: 0.6943 - val_accuracy: 0.4283
# Epoch 2/145
# 4951/4951 - 1s - loss: 0.6828 - accuracy: 0.6887 - val_loss: 0.6815 - val_accuracy: 0.5535
# Epoch 3/145
# 4951/4951 - 2s - loss: 0.6658 - accuracy: 0.7324 - val_loss: 0.6479 - val_accuracy: 0.7241
# Epoch 4/145
# 4951/4951 - 2s - loss: 0.6407 - accuracy: 0.7449 - val_loss: 0.6309 - val_accuracy: 0.6878
# Epoch 5/145
# 4951/4951 - 1s - loss: 0.6055 - accuracy: 0.7417 - val_loss: 0.6240 - val_accuracy: 0.6606
# Epoch 6/145
# 4951/4951 - 2s - loss: 0.5677 - accuracy: 0.7435 - val_loss: 0.5565 - val_accuracy: 0.7586
# Epoch 7/145
# 4951/4951 - 1s - loss: 0.5362 - accuracy: 0.7548 - val_loss: 0.5463 - val_accuracy: 0.7532
# Epoch 8/145
# 4951/4951 - 1s - loss: 0.5120 - accuracy: 0.7603 - val_loss: 0.4897 - val_accuracy: 0.8094
# Epoch 9/145
# 4951/4951 - 2s - loss: 0.4945 - accuracy: 0.7706 - val_loss: 0.4997 - val_accuracy: 0.8004
# Epoch 10/145
# 4951/4951 - 1s - loss: 0.4818 - accuracy: 0.7752 - val_loss: 0.5187 - val_accuracy: 0.7858
# Epoch 11/145
# 4951/4951 - 1s - loss: 0.4713 - accuracy: 0.7788 - val_loss: 0.5033 - val_accuracy: 0.8004
# Epoch 12/145
# 4951/4951 - 2s - loss: 0.4638 - accuracy: 0.7833 - val_loss: 0.4960 - val_accuracy: 0.8022
# Epoch 13/145
# 4951/4951 - 1s - loss: 0.4582 - accuracy: 0.7841 - val_loss: 0.4878 - val_accuracy: 0.8076
# Epoch 14/145
# 4951/4951 - 1s - loss: 0.4540 - accuracy: 0.7851 - val_loss: 0.5364 - val_accuracy: 0.7804
# Epoch 15/145
# 4951/4951 - 1s - loss: 0.4506 - accuracy: 0.7879 - val_loss: 0.5135 - val_accuracy: 0.7967
# Epoch 16/145
# 4951/4951 - 1s - loss: 0.4486 - accuracy: 0.7889 - val_loss: 0.5243 - val_accuracy: 0.7895
# Epoch 17/145
# 4951/4951 - 1s - loss: 0.4467 - accuracy: 0.7895 - val_loss: 0.5080 - val_accuracy: 0.8058
# Epoch 18/145
# 4951/4951 - 1s - loss: 0.4447 - accuracy: 0.7897 - val_loss: 0.5041 - val_accuracy: 0.8058
# Epoch 19/145
# 4951/4951 - 2s - loss: 0.4429 - accuracy: 0.7914 - val_loss: 0.4811 - val_accuracy: 0.8149
# Epoch 20/145
# 4951/4951 - 2s - loss: 0.4420 - accuracy: 0.7893 - val_loss: 0.4719 - val_accuracy: 0.8185
# Epoch 21/145
# 4951/4951 - 2s - loss: 0.4407 - accuracy: 0.7897 - val_loss: 0.4996 - val_accuracy: 0.8040
# Epoch 22/145
# 4951/4951 - 2s - loss: 0.4399 - accuracy: 0.7897 - val_loss: 0.4669 - val_accuracy: 0.8185
# Epoch 23/145
# 4951/4951 - 2s - loss: 0.4390 - accuracy: 0.7926 - val_loss: 0.4475 - val_accuracy: 0.8330
# Epoch 24/145
# 4951/4951 - 2s - loss: 0.4380 - accuracy: 0.7940 - val_loss: 0.4077 - val_accuracy: 0.8711
# Epoch 25/145
# 4951/4951 - 2s - loss: 0.4381 - accuracy: 0.7944 - val_loss: 0.5064 - val_accuracy: 0.7949
# Epoch 26/145
# 4951/4951 - 1s - loss: 0.4372 - accuracy: 0.7914 - val_loss: 0.4750 - val_accuracy: 0.8131
# Epoch 27/145
# 4951/4951 - 1s - loss: 0.4362 - accuracy: 0.7926 - val_loss: 0.4719 - val_accuracy: 0.8131
# Epoch 28/145
# 4951/4951 - 2s - loss: 0.4358 - accuracy: 0.7952 - val_loss: 0.5000 - val_accuracy: 0.8058
# Epoch 29/145
# 4951/4951 - 2s - loss: 0.4351 - accuracy: 0.7940 - val_loss: 0.4887 - val_accuracy: 0.8113
# Epoch 30/145
# 4951/4951 - 2s - loss: 0.4338 - accuracy: 0.7932 - val_loss: 0.4848 - val_accuracy: 0.8113
# Epoch 31/145
# 4951/4951 - 1s - loss: 0.4337 - accuracy: 0.7956 - val_loss: 0.4863 - val_accuracy: 0.8113
# Epoch 32/145
# 4951/4951 - 2s - loss: 0.4327 - accuracy: 0.7962 - val_loss: 0.5084 - val_accuracy: 0.8094
# Epoch 33/145
# 4951/4951 - 1s - loss: 0.4322 - accuracy: 0.7972 - val_loss: 0.4388 - val_accuracy: 0.8475
# Epoch 34/145
# 4951/4951 - 1s - loss: 0.4320 - accuracy: 0.7954 - val_loss: 0.4738 - val_accuracy: 0.8167
# Epoch 35/145
# 4951/4951 - 1s - loss: 0.4314 - accuracy: 0.7984 - val_loss: 0.4463 - val_accuracy: 0.8457
# Epoch 36/145
# 4951/4951 - 2s - loss: 0.4308 - accuracy: 0.7974 - val_loss: 0.4662 - val_accuracy: 0.8240
# Epoch 37/145
# 4951/4951 - 1s - loss: 0.4301 - accuracy: 0.7994 - val_loss: 0.4253 - val_accuracy: 0.8621
# Epoch 38/145
# 4951/4951 - 1s - loss: 0.4304 - accuracy: 0.7974 - val_loss: 0.4671 - val_accuracy: 0.8221
# Epoch 39/145
# 4951/4951 - 1s - loss: 0.4293 - accuracy: 0.7992 - val_loss: 0.5576 - val_accuracy: 0.7641
# Epoch 40/145
# 4951/4951 - 1s - loss: 0.4290 - accuracy: 0.8021 - val_loss: 0.4869 - val_accuracy: 0.8094
# Epoch 41/145
# 4951/4951 - 1s - loss: 0.4288 - accuracy: 0.7988 - val_loss: 0.4512 - val_accuracy: 0.8367
# Epoch 42/145
# 4951/4951 - 1s - loss: 0.4282 - accuracy: 0.7978 - val_loss: 0.4808 - val_accuracy: 0.8113
# Epoch 43/145
# 4951/4951 - 1s - loss: 0.4277 - accuracy: 0.8006 - val_loss: 0.4752 - val_accuracy: 0.8167
# Epoch 44/145
# 4951/4951 - 1s - loss: 0.4272 - accuracy: 0.7980 - val_loss: 0.4661 - val_accuracy: 0.8240
# Epoch 45/145
# 4951/4951 - 1s - loss: 0.4272 - accuracy: 0.8004 - val_loss: 0.5055 - val_accuracy: 0.8058
# Epoch 46/145
# 4951/4951 - 2s - loss: 0.4266 - accuracy: 0.8033 - val_loss: 0.4692 - val_accuracy: 0.8240
# Epoch 47/145
# 4951/4951 - 1s - loss: 0.4258 - accuracy: 0.8031 - val_loss: 0.4628 - val_accuracy: 0.8276
# Epoch 48/145
# 4951/4951 - 2s - loss: 0.4254 - accuracy: 0.8029 - val_loss: 0.4270 - val_accuracy: 0.8621
# Epoch 49/145
# 4951/4951 - 2s - loss: 0.4253 - accuracy: 0.8035 - val_loss: 0.4684 - val_accuracy: 0.8258
# Epoch 50/145
# 4951/4951 - 1s - loss: 0.4245 - accuracy: 0.8055 - val_loss: 0.4811 - val_accuracy: 0.8149
# Epoch 51/145
# 4951/4951 - 2s - loss: 0.4243 - accuracy: 0.8049 - val_loss: 0.4634 - val_accuracy: 0.8258
# Epoch 52/145
# 4951/4951 - 2s - loss: 0.4239 - accuracy: 0.8043 - val_loss: 0.4742 - val_accuracy: 0.8203
# Epoch 53/145
# 4951/4951 - 2s - loss: 0.4232 - accuracy: 0.8063 - val_loss: 0.4493 - val_accuracy: 0.8439
# Epoch 54/145
# 4951/4951 - 1s - loss: 0.4228 - accuracy: 0.8055 - val_loss: 0.4569 - val_accuracy: 0.8294
# Epoch 55/145
# 4951/4951 - 2s - loss: 0.4223 - accuracy: 0.8073 - val_loss: 0.4451 - val_accuracy: 0.8457
# Epoch 56/145
# 4951/4951 - 2s - loss: 0.4213 - accuracy: 0.8061 - val_loss: 0.4462 - val_accuracy: 0.8494
# Epoch 57/145
# 4951/4951 - 1s - loss: 0.4212 - accuracy: 0.8081 - val_loss: 0.4446 - val_accuracy: 0.8439
# Epoch 58/145
# 4951/4951 - 1s - loss: 0.4208 - accuracy: 0.8077 - val_loss: 0.4991 - val_accuracy: 0.8094
# Epoch 59/145
# 4951/4951 - 1s - loss: 0.4203 - accuracy: 0.8099 - val_loss: 0.4999 - val_accuracy: 0.8131
# Epoch 60/145
# 4951/4951 - 1s - loss: 0.4198 - accuracy: 0.8073 - val_loss: 0.4715 - val_accuracy: 0.8276
# Epoch 61/145
# 4951/4951 - 2s - loss: 0.4193 - accuracy: 0.8069 - val_loss: 0.4469 - val_accuracy: 0.8475
# Epoch 62/145
# 4951/4951 - 2s - loss: 0.4194 - accuracy: 0.8091 - val_loss: 0.5062 - val_accuracy: 0.8094
# Epoch 63/145
# 4951/4951 - 1s - loss: 0.4181 - accuracy: 0.8085 - val_loss: 0.4982 - val_accuracy: 0.8149
# Epoch 64/145
# 4951/4951 - 1s - loss: 0.4182 - accuracy: 0.8091 - val_loss: 0.4438 - val_accuracy: 0.8494
# Epoch 65/145
# 4951/4951 - 1s - loss: 0.4173 - accuracy: 0.8132 - val_loss: 0.5016 - val_accuracy: 0.8113
# Epoch 66/145
# 4951/4951 - 1s - loss: 0.4172 - accuracy: 0.8103 - val_loss: 0.4691 - val_accuracy: 0.8367
# Epoch 67/145
# 4951/4951 - 1s - loss: 0.4169 - accuracy: 0.8111 - val_loss: 0.4654 - val_accuracy: 0.8348
# Epoch 68/145
# 4951/4951 - 1s - loss: 0.4172 - accuracy: 0.8105 - val_loss: 0.4676 - val_accuracy: 0.8367
# Epoch 69/145
# 4951/4951 - 1s - loss: 0.4158 - accuracy: 0.8081 - val_loss: 0.5368 - val_accuracy: 0.7931
# Epoch 70/145
# 4951/4951 - 1s - loss: 0.4156 - accuracy: 0.8109 - val_loss: 0.4400 - val_accuracy: 0.8494
# Epoch 71/145
# 4951/4951 - 1s - loss: 0.4145 - accuracy: 0.8118 - val_loss: 0.4511 - val_accuracy: 0.8457
# Epoch 72/145
# 4951/4951 - 2s - loss: 0.4149 - accuracy: 0.8130 - val_loss: 0.4330 - val_accuracy: 0.8512
# Epoch 73/145
# 4951/4951 - 2s - loss: 0.4143 - accuracy: 0.8120 - val_loss: 0.4900 - val_accuracy: 0.8240
# Epoch 74/145
# 4951/4951 - 2s - loss: 0.4136 - accuracy: 0.8172 - val_loss: 0.4210 - val_accuracy: 0.8548
# Epoch 75/145
# 4951/4951 - 1s - loss: 0.4134 - accuracy: 0.8126 - val_loss: 0.4680 - val_accuracy: 0.8403
# Epoch 76/145
# 4951/4951 - 1s - loss: 0.4133 - accuracy: 0.8156 - val_loss: 0.4751 - val_accuracy: 0.8294
# Epoch 77/145
# 4951/4951 - 2s - loss: 0.4133 - accuracy: 0.8146 - val_loss: 0.4190 - val_accuracy: 0.8693
# Epoch 78/145
# 4951/4951 - 1s - loss: 0.4123 - accuracy: 0.8142 - val_loss: 0.4482 - val_accuracy: 0.8421
# Epoch 79/145
# 4951/4951 - 1s - loss: 0.4116 - accuracy: 0.8152 - val_loss: 0.4665 - val_accuracy: 0.8403
# Epoch 80/145
# 4951/4951 - 2s - loss: 0.4113 - accuracy: 0.8158 - val_loss: 0.4676 - val_accuracy: 0.8367
# Epoch 81/145
# 4951/4951 - 2s - loss: 0.4114 - accuracy: 0.8202 - val_loss: 0.4752 - val_accuracy: 0.8312
# Epoch 82/145
# 4951/4951 - 1s - loss: 0.4108 - accuracy: 0.8184 - val_loss: 0.4440 - val_accuracy: 0.8421
# Epoch 83/145
# 4951/4951 - 1s - loss: 0.4100 - accuracy: 0.8158 - val_loss: 0.4486 - val_accuracy: 0.8421
# Epoch 84/145
# 4951/4951 - 2s - loss: 0.4095 - accuracy: 0.8184 - val_loss: 0.4020 - val_accuracy: 0.8748
# Epoch 85/145
# 4951/4951 - 2s - loss: 0.4093 - accuracy: 0.8202 - val_loss: 0.4572 - val_accuracy: 0.8403
# Epoch 86/145
# 4951/4951 - 2s - loss: 0.4090 - accuracy: 0.8178 - val_loss: 0.4870 - val_accuracy: 0.8294
# Epoch 87/145
# 4951/4951 - 2s - loss: 0.4090 - accuracy: 0.8186 - val_loss: 0.4608 - val_accuracy: 0.8403
# Epoch 88/145
# 4951/4951 - 2s - loss: 0.4082 - accuracy: 0.8204 - val_loss: 0.4579 - val_accuracy: 0.8439
# Epoch 89/145
# 4951/4951 - 2s - loss: 0.4077 - accuracy: 0.8241 - val_loss: 0.4202 - val_accuracy: 0.8693
# Epoch 90/145
# 4951/4951 - 1s - loss: 0.4070 - accuracy: 0.8217 - val_loss: 0.4486 - val_accuracy: 0.8421
# Epoch 91/145
# 4951/4951 - 1s - loss: 0.4070 - accuracy: 0.8217 - val_loss: 0.4411 - val_accuracy: 0.8475
# Epoch 92/145
# 4951/4951 - 1s - loss: 0.4060 - accuracy: 0.8221 - val_loss: 0.4211 - val_accuracy: 0.8675
# Epoch 93/145
# 4951/4951 - 1s - loss: 0.4065 - accuracy: 0.8243 - val_loss: 0.4598 - val_accuracy: 0.8385
# Epoch 94/145
# 4951/4951 - 1s - loss: 0.4058 - accuracy: 0.8223 - val_loss: 0.4314 - val_accuracy: 0.8530
# Epoch 95/145
# 4951/4951 - 1s - loss: 0.4057 - accuracy: 0.8235 - val_loss: 0.4316 - val_accuracy: 0.8548
# Epoch 96/145
# 4951/4951 - 1s - loss: 0.4049 - accuracy: 0.8245 - val_loss: 0.4316 - val_accuracy: 0.8548
# Epoch 97/145
# 4951/4951 - 1s - loss: 0.4046 - accuracy: 0.8239 - val_loss: 0.4437 - val_accuracy: 0.8530
# Epoch 98/145
# 4951/4951 - 1s - loss: 0.4044 - accuracy: 0.8267 - val_loss: 0.4660 - val_accuracy: 0.8348
# Epoch 99/145
# 4951/4951 - 1s - loss: 0.4035 - accuracy: 0.8241 - val_loss: 0.4552 - val_accuracy: 0.8439
# Epoch 100/145
# 4951/4951 - 1s - loss: 0.4038 - accuracy: 0.8259 - val_loss: 0.4544 - val_accuracy: 0.8439
# Epoch 101/145
# 4951/4951 - 1s - loss: 0.4023 - accuracy: 0.8275 - val_loss: 0.4304 - val_accuracy: 0.8657
# Epoch 102/145
# 4951/4951 - 1s - loss: 0.4028 - accuracy: 0.8285 - val_loss: 0.4234 - val_accuracy: 0.8657
# Epoch 103/145
# 4951/4951 - 2s - loss: 0.4013 - accuracy: 0.8237 - val_loss: 0.4663 - val_accuracy: 0.8348
# Epoch 104/145
# 4951/4951 - 1s - loss: 0.4027 - accuracy: 0.8243 - val_loss: 0.4387 - val_accuracy: 0.8584
# Epoch 105/145
# 4951/4951 - 2s - loss: 0.4015 - accuracy: 0.8275 - val_loss: 0.4407 - val_accuracy: 0.8494
# Epoch 106/145
# 4951/4951 - 2s - loss: 0.4009 - accuracy: 0.8273 - val_loss: 0.4597 - val_accuracy: 0.8403
# Epoch 107/145
# 4951/4951 - 2s - loss: 0.4008 - accuracy: 0.8273 - val_loss: 0.4571 - val_accuracy: 0.8457
# Epoch 108/145
# 4951/4951 - 2s - loss: 0.4004 - accuracy: 0.8281 - val_loss: 0.4806 - val_accuracy: 0.8240
# Epoch 109/145
# 4951/4951 - 2s - loss: 0.3997 - accuracy: 0.8291 - val_loss: 0.4233 - val_accuracy: 0.8639
# Epoch 110/145
# 4951/4951 - 2s - loss: 0.3990 - accuracy: 0.8269 - val_loss: 0.4635 - val_accuracy: 0.8403
# Epoch 111/145
# 4951/4951 - 2s - loss: 0.3989 - accuracy: 0.8299 - val_loss: 0.4569 - val_accuracy: 0.8385
# Epoch 112/145
# 4951/4951 - 2s - loss: 0.3992 - accuracy: 0.8287 - val_loss: 0.4858 - val_accuracy: 0.8185
# Epoch 113/145
# 4951/4951 - 2s - loss: 0.3989 - accuracy: 0.8267 - val_loss: 0.4255 - val_accuracy: 0.8657
# Epoch 114/145
# 4951/4951 - 2s - loss: 0.3980 - accuracy: 0.8293 - val_loss: 0.4033 - val_accuracy: 0.8693
# Epoch 115/145
# 4951/4951 - 2s - loss: 0.3976 - accuracy: 0.8287 - val_loss: 0.4657 - val_accuracy: 0.8367
# Epoch 116/145
# 4951/4951 - 2s - loss: 0.3975 - accuracy: 0.8291 - val_loss: 0.4243 - val_accuracy: 0.8621
# Epoch 117/145
# 4951/4951 - 2s - loss: 0.3975 - accuracy: 0.8309 - val_loss: 0.4391 - val_accuracy: 0.8530
# Epoch 118/145
# 4951/4951 - 2s - loss: 0.3964 - accuracy: 0.8311 - val_loss: 0.4878 - val_accuracy: 0.8276
# Epoch 119/145
# 4951/4951 - 2s - loss: 0.3964 - accuracy: 0.8315 - val_loss: 0.4292 - val_accuracy: 0.8603
# Epoch 120/145
# 4951/4951 - 2s - loss: 0.3964 - accuracy: 0.8303 - val_loss: 0.4460 - val_accuracy: 0.8439
# Epoch 121/145
# 4951/4951 - 2s - loss: 0.3955 - accuracy: 0.8320 - val_loss: 0.4319 - val_accuracy: 0.8548
# Epoch 122/145
# 4951/4951 - 2s - loss: 0.3959 - accuracy: 0.8315 - val_loss: 0.4442 - val_accuracy: 0.8512
# Epoch 123/145
# 4951/4951 - 2s - loss: 0.3949 - accuracy: 0.8315 - val_loss: 0.4374 - val_accuracy: 0.8566
# Epoch 124/145
# 4951/4951 - 2s - loss: 0.3944 - accuracy: 0.8315 - val_loss: 0.4203 - val_accuracy: 0.8621
# Epoch 125/145
# 4951/4951 - 2s - loss: 0.3940 - accuracy: 0.8338 - val_loss: 0.4439 - val_accuracy: 0.8475
# Epoch 126/145
# 4951/4951 - 2s - loss: 0.3936 - accuracy: 0.8313 - val_loss: 0.4369 - val_accuracy: 0.8512
# Epoch 127/145
# 4951/4951 - 1s - loss: 0.3933 - accuracy: 0.8315 - val_loss: 0.4649 - val_accuracy: 0.8403
# Epoch 128/145
# 4951/4951 - 1s - loss: 0.3927 - accuracy: 0.8318 - val_loss: 0.4502 - val_accuracy: 0.8457
# Epoch 129/145
# 4951/4951 - 1s - loss: 0.3926 - accuracy: 0.8326 - val_loss: 0.4516 - val_accuracy: 0.8457
# Epoch 130/145
# 4951/4951 - 1s - loss: 0.3925 - accuracy: 0.8328 - val_loss: 0.4286 - val_accuracy: 0.8512
# Epoch 131/145
# 4951/4951 - 1s - loss: 0.3921 - accuracy: 0.8324 - val_loss: 0.5013 - val_accuracy: 0.8221
# Epoch 132/145
# 4951/4951 - 1s - loss: 0.3916 - accuracy: 0.8315 - val_loss: 0.4047 - val_accuracy: 0.8621
# Epoch 133/145
# 4951/4951 - 2s - loss: 0.3909 - accuracy: 0.8336 - val_loss: 0.4523 - val_accuracy: 0.8421
# Epoch 134/145
# 4951/4951 - 2s - loss: 0.3906 - accuracy: 0.8336 - val_loss: 0.4265 - val_accuracy: 0.8603
# Epoch 135/145
# 4951/4951 - 2s - loss: 0.3892 - accuracy: 0.8354 - val_loss: 0.3607 - val_accuracy: 0.8893
# Epoch 136/145
# 4951/4951 - 2s - loss: 0.3904 - accuracy: 0.8318 - val_loss: 0.4436 - val_accuracy: 0.8530
# Epoch 137/145
# 4951/4951 - 1s - loss: 0.3892 - accuracy: 0.8340 - val_loss: 0.4413 - val_accuracy: 0.8494
# Epoch 138/145
# 4951/4951 - 2s - loss: 0.3895 - accuracy: 0.8356 - val_loss: 0.4407 - val_accuracy: 0.8475
# Epoch 139/145
# 4951/4951 - 2s - loss: 0.3890 - accuracy: 0.8332 - val_loss: 0.4158 - val_accuracy: 0.8621
# Epoch 140/145
# 4951/4951 - 2s - loss: 0.3886 - accuracy: 0.8324 - val_loss: 0.3896 - val_accuracy: 0.8766
# Epoch 141/145
# 4951/4951 - 1s - loss: 0.3882 - accuracy: 0.8350 - val_loss: 0.4340 - val_accuracy: 0.8530
# Epoch 142/145
# 4951/4951 - 1s - loss: 0.3877 - accuracy: 0.8356 - val_loss: 0.4114 - val_accuracy: 0.8603
# Epoch 143/145
# 4951/4951 - 2s - loss: 0.3869 - accuracy: 0.8368 - val_loss: 0.3952 - val_accuracy: 0.8730
# Epoch 144/145
# 4951/4951 - 2s - loss: 0.3874 - accuracy: 0.8358 - val_loss: 0.4079 - val_accuracy: 0.8639
# Epoch 145/145
# 4951/4951 - 2s - loss: 0.3866 - accuracy: 0.8356 - val_loss: 0.3886 - val_accuracy: 0.8766

# %%
user_input=input("Enter the values one by one")
user_input=user_input.split(",")


for i in range(len(user_input)):
    # convert each item to int type
    user_input[i] = float(user_input[i])
# Out:
# Enter the values one by one1,67,147,2,1,1,228.69,36.60,1

# %%
user_input = np.array(user_input)
user_input = user_input.reshape(1,-1)
user_input = x_scaler.transform(user_input)
pred = model.predict(user_input)
output = np.argmax(pred[0])
if(output== 1):
  print("Warning! You have chances of getting a stroke!")
else:
  print("You are healthy and are less likely to get a stroke!")
# Out:
# Warning! You have chances of getting a stroke!

# %%
model.save("final_model.h5")

# %%
import sklearn
from pyngrok import ngrok

# %%
# %%writefile stroke.py
import streamlit as st
import base64
import sklearn
import numpy as np
import pickle as pkl
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow import keras
scal=MinMaxScaler()
#Load the saved model

model = tf.keras.models.load_model('final_model.h5')



st.set_page_config(page_title="Stroke prediction app ",page_icon="smiley",layout="centered",initial_sidebar_state="expanded")



def preprocess(gender,age,hypertension,alcohol_take,heart_disease,residence_type,avg_glucose_level,bmi,smoking_status ):   
 
    
    # Pre-processing user input   
    if gender=="male":
        gender=1 
    else: gender=0
	
    if heart_disease =="Yes":
        heart_disease = 1
    else:
        heart_disease = 0
    
    
    if residence_type=="Urban":
        residence_type=1
    else: residence_type = 0
	
    
    if smoking_status=="formely smoked":
        smoking_status = 1
    elif smoking_status=="never smoked":
        smoking_status = 2
    else:
        smoking_status =3
	
	


    user_input=[gender,age,hypertension,alcohol_take,residence_type,avg_glucose_level,bmi,smoking_status]
    user_input=np.array(user_input)
    user_input=user_input.reshape(1,-1)
    user_input=scal.fit_transform(user_input)
    prediction = model.predict(user_input)

    return prediction

    

       
    # front end elements of the web page 
html_temp = """ 
    <div style ="background-color:pink;padding:13px"> 
    <h1 style ="color:black;text-align:center;">Stroke Prediction App</h1> 
    </div> 
    """
      
# display the front end aspect
st.markdown(html_temp, unsafe_allow_html = True) 
st.subheader('by leesa-menezes ')
      
# following lines create boxes in which user can enter data required to make prediction
gender= st.radio("Select Gender: ", ('male', 'female'))
age=st.text_input("Age","Enter here")
hypertension =st.text_input("Hypertension","Enter here")
alcohol_take = st.text_input("Alcohol intake", "Please enter the amount of glasses consumed daily")
heart_disease= st.radio("Select you have a heart disease or not: ", ('Yes', 'No'))
residence_type= st.radio("Select your Residence Type: ", ('Urban', 'Rural'))
avg_glucose_level=st.text_input("Average Glucose Level","Please enter your value here")
bmi=st.text_input("BMI","Enter here")
smoking_status= st.radio("Select your smoking status: ", ('formely smoked', 'never smoked', 'smokes'))


#user_input=preprocess(sex,cp,exang, fbs, slope, thal )
pred=preprocess(gender,age,hypertension,alcohol_take,heart_disease,residence_type,avg_glucose_level,bmi,smoking_status)

output = np.argmax(pred[0])


if st.button("Predict"):    
  if output == 1:
    st.error('Warning! You have high risk of getting a stroke!')
    
  else:
    st.success('You have lower risk of getting a stroke!')
    
   



st.sidebar.subheader("About App")

st.sidebar.info("This web app is helps you to find out whether you are at a risk of developing a heart disease.")
st.sidebar.info("Enter the required fields and click on the 'Predict' button to check whether you have a healthy heart")
st.sidebar.info("Don't forget to rate this app")



feedback = st.sidebar.slider('How much would you rate this app?',min_value=0,max_value=5,step=1)

if feedback:
  st.header("Thank you for rating the app!")
  st.info("Caution: This is just a prediction and not doctoral advice. Kindly see a doctor if you feel the symptoms persist.")
# Out:
# Overwriting stroke.py

# %%
# !nohup streamlit run stroke.py &
url = ngrok.connect(port='8501')
url
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-159ee22d6584> in <module>
# ----> 1 get_ipython().system('nohup streamlit run stroke.py &')
#       2 url = ngrok.connect(port='8501')
#       3 url
#
# ~\Anaconda3\lib\site-packages\ipykernel\zmqshell.py in system_piped(self, cmd)
#     630             # os.system() or use ip.system=ip.system_raw
#     631             # if they really want a background process.
# --> 632             raise OSError("Background processes not supported.")
#     633
#     634         # we explicitly do NOT return the subprocess status code, because
#
# OSError: Background processes not supported.
